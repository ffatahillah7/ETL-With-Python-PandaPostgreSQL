# %% [markdown]
# # Extract, Transform, and Load dataset from CSV to PostgreSQL using Python pandas SQL library

# %% [markdown]
# ## Library Preparation

# %%
# Import Library
import pandas as pd
from pandasql import sqldf
from sqlalchemy import create_engine

# %% [markdown]
# ## Database Configuration

# %%
# config postgreSQL connection
db_uri = 'postgresql+psycopg2://postgres:A321654z@localhost:5432/mydb'

# Create Engine from SQLAlchemy for connection
engine = create_engine(db_uri)

# %% [markdown]
# ## Extract Dataset from CSV (read dataset)

# %%
# extract from your directory folder
df_covid = pd.read_csv('C:\\Users\\ffatahillah\Documents\\Data Engineer\\de_basic_class_etl-main\\dataset\owid-covid-data.csv')

# show dataset for first 10 rows
df_covid.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-12          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-19          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-26          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-02-02          NaN        0.0
# 5      AFG      Asia  Afghanistan  2020-02-09          NaN        0.0
# 6      AFG      Asia  Afghanistan  2020-02-16          NaN        0.0
# 7      AFG      Asia  Afghanistan  2020-02-23          NaN        0.0
# 8      AFG      Asia  Afghanistan  2020-03-01          1.0        1.0
# 9      AFG      Asia  Afghanistan  2020-03-08          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
# 5               0.000           NaN         0.0                  0.0  ...
# 6               0.000           NaN         0.0                  0.0  ...
# 7               0.000           NaN         0.0                  0.0  ...
# 8               0.143           NaN         0.0                  0.0  ...
# 9               0.143           NaN         0.0                  0.0  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
# 5           NaN                  37.746                         0.5
# 6           NaN                  37.746                         0.5
# 7           NaN                  37.746                         0.5
# 8           NaN                  37.746                         0.5
# 9           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
# 5            64.83                    0.511  41128772.0
# 6            64.83                    0.511  41128772.0
# 7            64.83                    0.511  41128772.0
# 8            64.83                    0.511  41128772.0
# 9            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# 5                                   NaN                          NaN
# 6                                   NaN                          NaN
# 7                                   NaN                          NaN
# 8                                   NaN                          NaN
# 9                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
# 5               NaN                                      NaN
# 6               NaN                                      NaN
# 7               NaN                                      NaN
# 8               NaN                                      NaN
# 9               NaN                                      NaN
#
# [10 rows x 67 columns]

# %% [markdown]
# ## Transform : Use Panda SQL to Query the dataset with SQL query format

# %%
df_covid.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.096600e+04  2.207800e+04        2.154800e+04  1.983900e+04
# mean   7.304802e+06  7.024754e+04        7.192026e+04  7.400694e+04
# std    3.770444e+07  6.620346e+05        5.388750e+05  3.065899e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    9.771000e+03  3.000000e+00        1.228600e+01  1.380000e+02
# 50%    6.892100e+04  1.800000e+02        2.594285e+02  1.004000e+03
# 75%    7.142602e+05  3.249000e+03        3.826214e+03  1.279900e+04
# max    4.274656e+08  4.214242e+07        1.404208e+07  2.933299e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  22079.000000         21549.000000             20966.000000
# mean     506.601522           518.835668            112388.795670
# std     2926.716455          2836.137324            164351.514233
# min        0.000000             0.000000                 0.000000
# 25%        0.000000             0.000000              2977.753000
# 50%        1.000000             1.714000             31589.257000
# 75%       36.000000            44.714000            153492.929000
# max    60413.000000         54608.429000            739907.166000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           22078.000000                    21548.000000
# mean             1036.640940                     1060.266866
# std              3910.883603                     3206.484352
# min                 0.000000                        0.000000
# 25%                 0.508500                        4.183750
# 50%                47.345000                       77.627000
# 75%               582.074500                      706.901250
# max            193107.077000                    71483.706000
#
#        total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# count              19839.000000  ...  73920.000000            51565.000000
# mean                 926.254300  ...     31.657296               48.787493
# std                 1127.256876  ...     14.601895               32.801986
# min                    0.000000  ...      7.700000                2.735000
# 25%                   60.769500  ...     18.800000               16.603000
# 50%                  443.948000  ...     31.200000               47.964000
# 75%                 1515.600000  ...     42.500000               83.741000
# max                 5693.491000  ...     76.100000               97.164000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                90651.000000    111945.000000            100457.000000
# mean                     2.861258        73.437590                 0.726158
# std                      2.218291         7.820577                 0.155960
# min                      0.300000        53.280000                 0.397000
# 25%                      1.130000        67.440000                 0.594000
# 50%                      2.110000        75.090000                 0.756000
# 75%                      4.200000        79.380000                 0.851000
# max                     11.000000        84.860000                 0.955000
#
#          population  excess_mortality_cumulative_absolute  \
# count  1.199270e+05                           5377.000000
# mean   1.356723e+08                          30542.870420
# std    5.351088e+08                          67999.828586
# min    3.801000e+03                         -17779.200000
# 25%    1.201680e+06                            220.599990
# 50%    9.449000e+06                           7128.401000
# 75%    3.347587e+07                          36108.200000
# max    4.721383e+09                         868254.600000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  5377.000000       5377.000000
# mean                      9.511977         11.633115
# std                      12.027946         24.764266
# min                     -24.010000        -70.590000
# 25%                       2.130000         -0.740000
# 50%                       7.200000          6.210000
# 75%                      13.850000         16.560000
# max                      70.820000        377.630000
#
#        excess_mortality_cumulative_per_million
# count                              5377.000000
# mean                               1607.310303
# std                                1910.723910
# min                               -2424.691400
# 25%                                 138.446260
# 50%                                 994.333740
# 75%                                2619.328900
# max                               10292.916000
#
# [8 rows x 62 columns]

# %%
#transform process
#filter data total_case is not null
#and total_deaths is not null
#and location indonesia
#and new_deaths more than 5
df_idn = sqldf('''Select iso_code,continent,location,date,total_cases,new_cases,total_deaths,new_deaths,handwashing_facilities,hospital_beds_per_thousand,
human_development_index,population from df_covid where total_cases is not null and total_deaths is not null and location='Indonesia' and new_deaths > 5 ''')

df_idn
# Out:
#     iso_code continent   location        date  total_cases  new_cases  \
# 0        IDN      Asia  Indonesia  2020-03-22        514.0      397.0
# 1        IDN      Asia  Indonesia  2020-03-29       1285.0      771.0
# 2        IDN      Asia  Indonesia  2020-04-05       2273.0      988.0
# 3        IDN      Asia  Indonesia  2020-04-12       4241.0     1968.0
# 4        IDN      Asia  Indonesia  2020-04-19       6575.0     2334.0
# ..       ...       ...        ...         ...          ...        ...
# 174      IDN      Asia  Indonesia  2023-07-23    6812818.0      148.0
# 175      IDN      Asia  Indonesia  2023-07-30    6812966.0      148.0
# 176      IDN      Asia  Indonesia  2023-12-17    6817154.0     1998.0
# 177      IDN      Asia  Indonesia  2023-12-24    6819830.0     2676.0
# 178      IDN      Asia  Indonesia  2023-12-31    6820926.0     1096.0
#
#      total_deaths  new_deaths  handwashing_facilities  \
# 0            48.0        44.0                  64.204
# 1           114.0        66.0                  64.204
# 2           198.0        84.0                  64.204
# 3           373.0       175.0                  64.204
# 4           582.0       209.0                  64.204
# ..            ...         ...                     ...
# 174      161903.0         8.0                  64.204
# 175      161914.0        11.0                  64.204
# 176      161930.0         7.0                  64.204
# 177      161954.0        24.0                  64.204
# 178      161965.0        11.0                  64.204
#
#      hospital_beds_per_thousand  human_development_index   population
# 0                          1.04                    0.718  275501344.0
# 1                          1.04                    0.718  275501344.0
# 2                          1.04                    0.718  275501344.0
# 3                          1.04                    0.718  275501344.0
# 4                          1.04                    0.718  275501344.0
# ..                          ...                      ...          ...
# 174                        1.04                    0.718  275501344.0
# 175                        1.04                    0.718  275501344.0
# 176                        1.04                    0.718  275501344.0
# 177                        1.04                    0.718  275501344.0
# 178                        1.04                    0.718  275501344.0
#
# [179 rows x 12 columns]

# %% [markdown]
# ## Load to PostgreSQL

# %%
# count the data 
count_data = df_idn.shape[0]
count_data
# Out:
# 179

# %%
# Set Table Name
table_name = 'covid_idn'

#load to postgreSQL
df_idn.to_sql(name=table_name, con=engine, index=False, if_exists = 'append')

print(f'Total Record has been inserted are {count_data} to table {table_name} ')
# Out:
# Total Record has been inserted are 179 to table covid_idn
